# %%
import findspark
findspark.init('/home/spark/spark-2.1.0-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("LogregEx").getOrCreate()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
my_data  =  spark.read.format('libsvm').load('sample_libsvm_data.txt')

# %%
my_data.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[124,125,126...|
# |  1.0|(692,[152,153,154...|
# |  1.0|(692,[151,152,153...|
# |  0.0|(692,[129,130,131...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[99,100,101,...|
# |  0.0|(692,[154,155,156...|
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[154,155,156...|
# |  0.0|(692,[153,154,155...|
# |  0.0|(692,[151,152,153...|
# |  1.0|(692,[129,130,131...|
# |  0.0|(692,[154,155,156...|
# |  1.0|(692,[150,151,152...|
# |  0.0|(692,[124,125,126...|
# |  0.0|(692,[152,153,154...|
# |  1.0|(692,[97,98,99,12...|
# |  1.0|(692,[124,125,126...|
# +-----+--------------------+
# only showing top 20 rows

# %%
my_log_reg_mod = LogisticRegression()

# %%
fitteld_logreg =my_log_reg_mod.fit(my_data)

# %%
log_summary =fitteld_logreg.summary

# %%
log_summary.predictions.printSchema()
# Out:
# root
#  |-- label: double (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = true)

# %%
log_summary.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[127,128,129...|[19.8534775947478...|[0.99999999761359...|       0.0|
# |  1.0|(692,[158,159,160...|[-20.377398194908...|[1.41321555111056...|       1.0|
# |  1.0|(692,[124,125,126...|[-27.401459284891...|[1.25804865126979...|       1.0|
# |  1.0|(692,[152,153,154...|[-18.862741612668...|[6.42710509170303...|       1.0|
# |  1.0|(692,[151,152,153...|[-20.483011833009...|[1.27157209200604...|       1.0|
# |  0.0|(692,[129,130,131...|[19.8506078990277...|[0.99999999760673...|       0.0|
# |  1.0|(692,[158,159,160...|[-20.337256674833...|[1.47109814695581...|       1.0|
# |  1.0|(692,[99,100,101,...|[-19.595579753418...|[3.08850168102631...|       1.0|
# ...

# %%
lr_train, lr_test = my_data.randomSplit([0.7,0.3])

# %%
for i in lr_train.head(4)[0]:
    print(i)
    print('\n')
# Out:
# 0.0
#
#
# ...

# %%
final_model = LogisticRegression()

# %%
final_fit = final_model.fit(lr_train)

# %%
predections_and_labels  = final_fit.evaluate(lr_test)

# %%
predections_and_labels.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[122,123,148...|[14.8026066726458...|[0.99999962734286...|       0.0|
# |  0.0|(692,[124,125,126...|[22.7462574118583...|[0.99999999986774...|       0.0|
# |  0.0|(692,[126,127,128...|[25.7708377863824...|[0.99999999999357...|       0.0|
# |  0.0|(692,[126,127,128...|[28.1996054493343...|[0.99999999999943...|       0.0|
# |  0.0|(692,[126,127,128...|[30.0315936210222...|[0.99999999999990...|       0.0|
# |  0.0|(692,[127,128,129...|[22.9509899731822...|[0.99999999989222...|       0.0|
# |  0.0|(692,[152,153,154...|[17.2212121853139...|[0.99999996681647...|       0.0|
# |  0.0|(692,[152,153,154...|[13.3164098077674...|[0.99999835276338...|       0.0|
# ...

# %%
from pyspark.ml.evaluation import (BinaryClassificationEvaluator,MulticlassClassificationEvaluator)

# %%
my_eval = BinaryClassificationEvaluator()

# %%
result = my_eval.evaluate(predections_and_labels.predictions)

# %%
result
# Out:
# 1.0
